# %% [markdown]
# # 01 Data audit
# Metadata-only audit of the official Smart Turn v3.2 train set. Avoid decoding all audio.

# %%
import os, subprocess, sys
from pathlib import Path
repo = Path('/content/ShipRocket-assesment')
if not repo.exists():
    subprocess.check_call(['git', 'clone', 'https://github.com/Saaalil/ShipRocket-assesment.git', str(repo)])
os.chdir(repo)
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '-e', '.[train]'])

# %%
# !python scripts/audit_data.py --config configs/data.yaml --max-rows 20000
