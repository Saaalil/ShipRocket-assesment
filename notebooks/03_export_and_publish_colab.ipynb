# %% [markdown]
# # 03 Export and publish
# Export ONNX, benchmark CPU, then publish with a local Hugging Face token.

# %%
import os, subprocess, sys
from pathlib import Path
repo = Path('/content/ShipRocket-assesment')
os.chdir(repo)
# !python scripts/export_onnx.py --config configs/final.yaml
# !python scripts/benchmark_cpu.py --onnx artifacts/model_int8.onnx

# %%
# huggingface-cli login   # run interactively
# !python scripts/publish_model.py --repo Saalil/Assesment_SR-model
